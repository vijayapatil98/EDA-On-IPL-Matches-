# %% [markdown]
# # EDA of IPL Matches

# %% [markdown]
# # Import Libraries

# %%
#importing Required library 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#importing plotly Library
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf
py.offline.init_notebook_mode(connected=True) #Turning on notebook mode 
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
# ...

# %% [markdown]
# # To read File using Pandas

# %%
df=pd.read_csv(r"C:\Users\Lenovo\Desktop\matches (1).csv")

# %%
df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %% [raw]
# This dataset contains information about IPL Matches 2008-2020
# The columns in the given dataset are as follows:
#
# ID
# Season
# City
# Date
# Team1
# Team2
# Toss-Winner
# Toss-Decision
# Result
# dl-applied
# winner
# win by runs
# win by wickets
# Player of the match
# Venue
# Result-margin
# Eliminator
# Method
# Umpire1
# Umpire2
# umpire3

# %% [markdown]
# # Size of Columns and Rows using Shape Function

# %%
df.shape
# Out:
# (756, 18)

# %% [markdown]
# In the given Dataset, There are 816 Rows and 17 Columns.

# %% [markdown]
# # First Top 5 Observation using head() function

# %%
df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # Bottom 5 Observation using tail() function

# %%
df.tail()
# Out:
#         id    Season           city        date                  team1  \
# 751  11347  IPL-2019         Mumbai  05-05-2019  Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019    Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019    Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019         Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# ...

# %% [markdown]
# # Information of Data Using Info Function

# %%
df.info
# Out:
# <bound method DataFrame.info of         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %% [markdown]
# # Name of column using column function

# %%
df.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %% [raw]
# Name of Column are using colums Function
#
# ID
# Season
# City
# Date
# Team1
# Team2
# Toss-Winner
# Toss-Decision
# Result
# dl-applied
# winner
# win by runs
# win by wickets
# Player of the match
# Venue
# Result-margin
# Eliminator
# Method
# Umpire1
# Umpire2
# umpire3

# %% [markdown]
# # To find out NaN Values in given Dataset

# %%
df.isna()
# Out:
#         id  Season   city   date  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 751  False   False  False  False  False  False        False          False
# 752  False   False  False  False  False  False        False          False
# 753  False   False  False  False  False  False        False          False
# 754  False   False  False  False  False  False        False          False
# 755  False   False  False  False  False  False        False          False
#
# ...

# %%
df.isna().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %% [markdown]
# # Heatmap for NaN Values

# %%
sns.heatmap(df.isna(), cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above heatmap it is clear that, Umpire and city has NaN Values

# %% [markdown]
# # Drop Values using drop function

# %%
df.dropna(how='any',inplace=True)

# %%
df.isna()
# Out:
#         id  Season   city   date  team1  team2  toss_winner  toss_decision  \
# 636  False   False  False  False  False  False        False          False
# 637  False   False  False  False  False  False        False          False
# 638  False   False  False  False  False  False        False          False
# 639  False   False  False  False  False  False        False          False
# 640  False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 750  False   False  False  False  False  False        False          False
# 751  False   False  False  False  False  False        False          False
# 752  False   False  False  False  False  False        False          False
# 754  False   False  False  False  False  False        False          False
# 755  False   False  False  False  False  False        False          False
#
# ...

# %%
df.isna().sum()
# Out:
# id                 0
# Season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# umpire3            0
# dtype: int64

# %% [markdown]
# # Heatmap after drop the NaN Values

# %%
sns.heatmap(df.isna(),cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# In the above Heatmap, There is no NaN Values.

# %% [markdown]
# # Some statistics using the Describe Function

# %%
df.describe()
# Out:
#                  id  dl_applied  win_by_runs  win_by_wickets
# count    118.000000  118.000000   118.000000      118.000000
# mean    9572.610169    0.025424    11.355932        3.271186
# std     1685.654201    0.158080    21.090981        3.233534
# min     7894.000000    0.000000     0.000000        0.000000
# 25%     7923.250000    0.000000     0.000000        0.000000
# 50%     7952.500000    0.000000     0.000000        4.000000
# 75%    11319.750000    0.000000    14.000000        6.000000
# max    11415.000000    1.000000   118.000000       10.000000

# %% [markdown]
# Some statistics using describe Function

# %%
df=pd.read_csv(r"C:\Users\Lenovo\Desktop\matches (1).csv")
df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %% [markdown]
# # How many season are played? using nunique()

# %%
df['Season'].nunique()
# Out:
# 12

# %%
df['Season'].unique()
# Out:
# array(['IPL-2017', 'IPL-2008', 'IPL-2009', 'IPL-2010', 'IPL-2011',
#        'IPL-2012', 'IPL-2013', 'IPL-2014', 'IPL-2015', 'IPL-2016',
#        'IPL-2018', 'IPL-2019'], dtype=object)

# %% [markdown]
# The number of season played 12
# The listing of ipl Season are IPL-2017 IPL-2008 IPL-2009 IPL-2010 IPL-2011
#        IPL-2012 IPL-2013 IPL-2014IPL-2015 IPL-2016
#        IPL-2018 IPL-2019

# %% [markdown]
# # The number of matches are played

# %%
df['id'].count()
# Out:
# 756

# %% [markdown]
# # Which team won by Maximum Runs?

# %%
df.iloc[df['win_by_runs'].idxmax()]
# Out:
# id                               44
# Season                     IPL-2017
# city                          Delhi
# date                     06-05-2017
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %% [markdown]
# # Which team won by Maximum wickets?

# %%
df.iloc[df['win_by_wickets'].idxmax()]
# Out:
# id                                                      3
# Season                                           IPL-2017
# city                                               Rajkot
# date                                           07-04-2017
# team1                                       Gujarat Lions
# team2                               Kolkata Knight Riders
# toss_winner                         Kolkata Knight Riders
# toss_decision                                       field
# result                                             normal
# dl_applied                                              0
# winner                              Kolkata Knight Riders
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# ...

# %% [markdown]
# # Which team won by Minimum Runs?

# %%
df.iloc[df['win_by_runs'].idxmin()]
# Out:
# id                                                       2
# Season                                            IPL-2017
# city                                                  Pune
# date                                            06-04-2017
# team1                                       Mumbai Indians
# team2                               Rising Pune Supergiant
# toss_winner                         Rising Pune Supergiant
# toss_decision                                        field
# result                                              normal
# dl_applied                                               0
# winner                              Rising Pune Supergiant
# win_by_runs                                              0
# win_by_wickets                                           7
# player_of_match                                  SPD Smith
# venue              Maharashtra Cricket Association Stadium
# umpire1                                     A Nand Kishore
# ...

# %% [markdown]
# # Which team won by Minimum wickets?

# %%
df.iloc[df['win_by_wickets'].idxmin()]
# Out:
# id                                                         1
# Season                                              IPL-2017
# city                                               Hyderabad
# date                                              05-04-2017
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
cat_cols = ['Season','result','toss_decision','winner']
i=0
while i < 4:
    fig = plt.figure(figsize=[20,5])   
    
    plt.subplot(1,2,1)
    sns.countplot(x=cat_cols[i], data=df)
    i += 1  
    
    plt.subplot(1,2,2)
    sns.countplot(x=cat_cols[i], data=df)
    i += 1
    
    plt.show()

# %% [raw]
# From above graph,
# 1)Season 2011,2012,2013 has consisted highest number of matches played.
# 2)Listing of result is higher than tie and no result
# 3)Field toss decision is higher than bat decision
# 4)Mumbai Indians is the higher number matches win.`

# %% [markdown]
# # Heatmap using correlation

# %%
corr=df.corr()
corr
# Out:
#                       id  dl_applied  win_by_runs  win_by_wickets
# id              1.000000   -0.011658    -0.039403       -0.012239
# dl_applied     -0.011658    1.000000    -0.016349       -0.011631
# win_by_runs    -0.039403   -0.016349     1.000000       -0.560420
# win_by_wickets -0.012239   -0.011631    -0.560420        1.000000

# %%
sns.heatmap(df.corr(), annot=True, cmap="RdBu")
plt.show()

# %% [raw]
# In the heatmap, Dark Blue Point has highly Correlated
# and Dark Red has lowest Correlated.

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df)

# %% [markdown]
# # What is probability of win if the toss was won?

# %%
probability_of_win = df['toss_winner'] == df['winner']

probability_of_win.groupby(probability_of_win).size()
# Out:
# False    363
# True     393
# dtype: int64

# %%
sns.countplot(probability_of_win)
# Out:
# C:\Users\Lenovo\.conda\envs\PY38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:ylabel='count'>

# %% [markdown]
# There is very small probability of chance to loose the match if team lost toss.

# %% [markdown]
# # Highest wins by teams per season

# %%
df.groupby('Season')['winner'].value_counts()
# Out:
# Season    winner
# IPL-2008  Rajasthan Royals               13
#           Kings XI Punjab                10
#           Chennai Super Kings             9
#           Delhi Daredevils                7
#           Mumbai Indians                  7
#                                          ..
# IPL-2019  Kings XI Punjab                 6
#           Kolkata Knight Riders           6
#           Sunrisers Hyderabad             6
#           Rajasthan Royals                5
#           Royal Challengers Bangalore     5
# Name: winner, Length: 100, dtype: int64

# %% [markdown]
# # In which city were the number of matches played?

# %%
df['city'].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: city, dtype: int64
